# %%
import pandas as pd
import requests
from brussels_bike_forecasting.src.data_fetching import get_sensor_devices_json, get_sensor_devices_dataframe

# %% [markdown]
# # Fetching Devices

# %%
get_sensor_devices_json()[0]
# Out:
# {'type': 'Feature',
#  'id': 'device.CAT17',
#  'geometry': {'type': 'Point',
#   'coordinates': [4.301991995919691, 50.820621002525904],
#   'geometry_name': 'geom'},
#  'properties': {'device_name': 'CAT17',
#   'active': True,
#   'road_nl': 'Veeweidekaai 11 - 1070 Anderlecht',
#   'road_fr': 'Quai de Veeweyde 11 - 1070 Anderlecht',
#   'road_en': 'Quai de Veeweyde 11 - 1070 Anderlecht',
#   'descr_nl': 'Veeweidekaai 11 - 1070 Anderlecht',
#   'descr_fr': 'Quai de Veeweyde 11 - 1070 Anderlecht',
#   'descr_en': 'Quai de Veeweyde 11 - 1070 Anderlecht',
#   'lane_schema': 'https://data.mobility.brussels/media/bike/count/CAT17_6b8e7a01-cc38-4d06-9a4d-3d4ece53a578.png',
#   'basic_schema': 'https://data.mobility.brussels/media/bike/count/CAT17_82c4bc7e-f1d0-43cc-9be5-8678af101c57.png',
#   'detailed_schema': 'https://data.mobility.brussels/media/bike/count/CAT17_9be1e6e1-4c00-4730-b747-a6b158b85a5b.png',
# ...

# %%
get_sensor_devices_dataframe()
# Out:
#    device_name   type                              coordinates  \
# 0        CAT17  Point  [4.301991995919691, 50.820621002525904]
# 1      CB02411  Point   [4.373960995908418, 50.88185000251615]
# 2       CB1101  Point    [4.36858299590588, 50.84534100252618]
# 3       CB1142  Point  [4.378737995903186, 50.843570002527876]
# 4       CB1143  Point   [4.378813995903146, 50.84337000252792]
# 5       CB1599  Point   [4.379253995899753, 50.81240800253699]
# 6       CB1699  Point   [4.378799995899851, 50.81228000253699]
# 7       CB2105  Point   [4.340009995912418, 50.84048000252439]
# 8       CEE016  Point   [4.386718995898861, 50.82137600253522]
# 9       CEK049  Point   [4.393892995897416, 50.82448000253513]
# 10       CEK18  Point   [4.400258995897405, 50.83920000253155]
# 11       CEK31  Point   [4.393037995899081, 50.83818200253104]
# 12      CEV011  Point   [4.402934995899683, 50.86692100252375]
# 13      CJE181  Point   [4.315713995922622, 50.88029700251005]
# ...
